# %% [markdown]
# <a href="https://colab.research.google.com/github/gvsmaneesha/t5_training/blob/main/Training_Instance_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd ~/../content
# Out:
# /content

# %%
# !rm -rf t5
# !git clone https://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@github.com/Nagakiran1/t5.git
# Out:
# Cloning into 't5'...
# remote: Enumerating objects: 83, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 83 (delta 29), reused 69 (delta 19), pack-reused 0
# Unpacking objects: 100% (83/83), done.

# %%
cd t5
# Out:
# /content/t5

# %%
ls -l
# Out:
# total 88
# drwxr-xr-x 2 root root  4096 Feb 28 09:18 config/
# drwxr-xr-x 2 root root  4096 Feb 28 09:18 datasets/
# drwxr-xr-x 3 root root  4096 Feb 28 09:18 learning_modules/
# -rw-r--r-- 1 root root  1067 Feb 28 09:18 LICENSE
# drwxr-xr-x 3 root root  4096 Feb 28 09:18 lightning_logs/
# -rw-r--r-- 1 root root  2072 Feb 28 09:18 main.py
# -rw-r--r-- 1 root root    47 Feb 28 09:18 README.md
# -rw-r--r-- 1 root root   107 Feb 28 09:18 requirements.txt
# -rw-r--r-- 1 root root 52661 Feb 28 09:18 Training_Instance_new.ipynb
# -rw-r--r-- 1 root root   687 Feb 28 09:18 utilization.py

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (1.21.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (1.3.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (0.1.96)
# Requirement already satisfied: torch!=1.8.0,>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (1.10.0+cu111)
# Requirement already satisfied: transformers==4.16.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (4.16.2)
# Requirement already satisfied: pytorch-lightning==1.5.10 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 6)) (1.5.10)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 7)) (6.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 8)) (3.2.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.16.2->-r requirements.txt (line 5)) (2.23.0)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.16.2->-r requirements.txt (line 5)) (0.11.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.16.2->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==4.16.2->-r requirements.txt (line 5)) (0.0.47)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.16.2->-r requirements.txt (line 5)) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.16.2->-r requirements.txt (line 5)) (4.62.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.16.2->-r requirements.txt (line 5)) (2019.12.20)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.16.2->-r requirements.txt (line 5)) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.16.2->-r requirements.txt (line 5)) (4.11.1)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (0.18.2)
# Requirement already satisfied: pyDeprecate==0.3.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (0.3.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (3.10.0.2)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (2.8.0)
# Requirement already satisfied: setuptools==59.5.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (59.5.0)
# Requirement already satisfied: torchmetrics>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (0.7.2)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (2022.2.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.16.2->-r requirements.txt (line 5)) (3.0.7)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (1.35.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (1.43.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (3.3.6)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (3.17.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (0.6.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.4->tensorboard>=2.2.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.16.2->-r requirements.txt (line 5)) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.16.2->-r requirements.txt (line 5)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.16.2->-r requirements.txt (line 5)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.16.2->-r requirements.txt (line 5)) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.16.2->-r requirements.txt (line 5)) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->-r requirements.txt (line 2)) (2018.9)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (2.0.12)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (21.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (0.13.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.16.2->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.16.2->-r requirements.txt (line 5)) (7.1.2)

# %%
data_dict = {"filename":"tweet_dataset.csv","input":["text","selected_text"],
             "output":["source_text","target_text"],
             "prefix":"Summarize:",
             "summary":"source_text"}

# %% [markdown]
# # New Section

# %%
from learning_modules.data_utils import create_dataset
train_df,test_df,eval_df = create_dataset(data_dict)
# Out:
# done with dataset

# %%
train_df.values[0]
# Out:
# array(['Summarize: we should all be down to earth. don`t none of us walk on water  I`m just some **** nerd trying to find my way thru life lol',
#        'we should all be down to earth. don`t none of us walk on water  I`m just some **** nerd trying to find my way thru life lol'],
#       dtype=object)

# %%
# command to run before code
! pip install spacy
! pip install nltk
! python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (2.2.4)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (59.5.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (7.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.62.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.21.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (4.11.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy) (3.10.0.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 20.6 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.6)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.62.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.6)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (59.5.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.21.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.11.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
text = ",".join(train_df["source_text"][0:30])

# %%
# imports and load spacy english language package
import spacy
from spacy import displacy
from spacy import tokenizer
nlp = spacy.load('en_core_web_sm')

doc = nlp(text)

sentences = list(doc.sents)
print(sentences)
# tokenization
for token in doc:
    print(token.text)
# print entities
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print(ents)
# now we use displaycy function on doc2
displacy.render(doc, style='ent', jupyter=True)
# Out:
# [Summarize: we should all be down to earth., don`t, none of us walk on water  I`m, just some, *, *, *, * nerd trying to find my way thru life lol,Summarize:, umm, how abt a comment like that :p, ', i dont like this',Summarize:Gotta go to the doctor this morning  , i feel so sick right now., i can barely talk but i`m, still yelling across the house lol,Summarize:, busy wit work  , how is your business going on?,Summarize, : I hope the young`ins enjoyed your wisdom!,Summarize:In a rush....   , Lunchtime anyway, ,Summarize: we had scones this afternoon!!, they were great  we`re, gonna make cupcakes this week, on Wednesday!,Summarize:G`day  , Thanx for following., ,Summarize, :, The $500 I saved on not buying a couch is going towards paying my visit to ER for UTI,Summarize:, Still at work whaaaaaaaahhhh,Summarize::, Oh., The voting is over!  , But don`t worry, I already voted for you about 100000000000000000000000000000000000 times earlier!!!,Summarize:, This is scary  , they hooked me up to 9 wires, n, it printed, sum graph ohhhhhh,Summarize:, just got done washing dishes not too long ago,Summarize:Just going to shower., Brb in 10 mins or so,Summarize:I`ve, lost my pocket knife  Suggestions for replacing a Ken Onion Chive?,Summarize:, dang, i miss you  goodnight, ,Summarize:, My goodness!, Another hit, another run!!!,Summarize:, Thinkin` Twitter is interesting., ,Summarize, : woohoo!, congrats to your friend and the boyfriend., ,Summarize:Buongiorno !!!, woke up and of for my Italian lunch,Summarize:gives you a Haiku status (inspired by Michelle Yuen)  , the sun is shining a perfect day glorious day outside my office,Summarize:  in chicago until 8:20  ..., just landed xoxo,Summarize:_uk Yeah, but it`s Myst!,Summarize, : I use to own a 32 lbs tabby cat., Got him for North Shore Animal league he had diabetes,Summarize:, boo,Summarize:, I had a horrible dream  it had to do with a scary face, now im awake for the rest of the night., God dammit :, \,Summarize:When you see someone without a smile pass them yours,Summarize:, hey girl i just sent ya a message on Myspace,Summarize: where`s, the love?,Summarize:, Oh ok,Thanks., Dont know where the courthouse id, either,I`ll learn though., Any nkotb?, Twitter stole my pic again  , it hates me]
# Summarize
# :
# we
# should
# all
# be
# down
# to
# earth
# .
# don`t
# none
# of
# us
# walk
# on
# water
#
# I`m
# just
# some
# *
# *
# *
# *
# nerd
# trying
# to
# find
# my
# way
# thru
# life
# lol
# ,
# Summarize
# :
# umm
# how
# abt
# a
# comment
# like
# that
# :p
# '
# i
# do
# nt
# like
# this',Summarize
# :
# Gotta
# go
# to
# the
# doctor
# this
# morning
#
# i
# feel
# so
# sick
# right
# now
# .
# i
# can
# barely
# talk
# but
# i`m
# still
# yelling
# across
# the
# house
# lol
# ,
# Summarize
# :
# busy
# wit
# work
#
# how
# is
# your
# business
# going
# on?,Summarize
# :
# I
# hope
# the
# young`ins
# enjoyed
# your
# wisdom!,Summarize
# :
# In
# a
# rush
# ....
#
# Lunchtime
# anyway
# ,
# Summarize
# :
# we
# had
# scones
# this
# afternoon
# !
# !
# they
# were
# great
#
# we`re
# gon
# na
# make
# cupcakes
# this
# week
# ,
# on
# Wednesday!,Summarize
# :
# G`day
#
# Thanx
# for
# following
# .
# ,Summarize
# :
# The
# $
# 500
# I
# saved
# on
# not
# buying
# a
# couch
# is
# going
# towards
# paying
# my
# visit
# to
# ER
# for
# UTI
# ,
# Summarize
# :
# Still
# at
# work
# whaaaaaaaahhhh
# ,
# Summarize
# :
# :
# Oh
# .
# The
# voting
# is
# over
# !
#
# But
# don`t
# worry
# ,
# I
# already
# voted
# for
# you
# about
# 100000000000000000000000000000000000
# times
# earlier!!!,Summarize
# :
# This
# is
# scary
#
# they
# hooked
# me
# up
# to
# 9
# wires
# n
# it
# printed
# sum
# graph
# ohhhhhh
# ,
# Summarize
# :
# just
# got
# done
# washing
# dishes
# not
# too
# long
# ago
# ,
# Summarize
# :
# Just
# going
# to
# shower
# .
# Brb
# in
# 10
# mins
# or
# so
# ,
# Summarize
# :
# I`ve
# lost
# my
# pocket
# knife
#
# Suggestions
# for
# replacing
# a
# Ken
# Onion
# Chive?,Summarize
# :
# dang
# i
# miss
# you
#
# goodnight
# ,
# Summarize
# :
# My
# goodness
# !
# Another
# hit
# ,
# another
# run!!!,Summarize
# :
# Thinkin
# `
# Twitter
# is
# interesting
# .
# ,Summarize
# :
# woohoo
# !
# congrats
# to
# your
# friend
# and
# the
# boyfriend
# .
# ,Summarize
# :
# Buongiorno
# !
# !
# !
# woke
# up
# and
# of
# for
# my
# Italian
# lunch
# ,
# Summarize
# :
# gives
# you
# a
# Haiku
# status
# (
# inspired
# by
# Michelle
# Yuen
# )
#
# the
# sun
# is
# shining
# a
# perfect
# day
# glorious
# day
# outside
# my
# office
# ,
# Summarize
# :
#
# in
# chicago
# until
# 8:20
#
# ...
# just
# landed
# xoxo
# ,
# Summarize:_uk
# Yeah
# ,
# but
# it`s
# Myst!,Summarize
# :
# I
# use
# to
# own
# a
# 32
# lbs
# tabby
# cat
# .
# Got
# him
# for
# North
# Shore
# Animal
# league
# he
# had
# diabetes
# ,
# Summarize
# :
# boo
# ,
# Summarize
# :
# I
# had
# a
# horrible
# dream
#
# it
# had
# to
# do
# with
# a
# scary
# face
# ,
# now
# i
# m
# awake
# for
# the
# rest
# of
# the
# night
# .
# God
# dammit
# :
# \,Summarize
# :
# When
# you
# see
# someone
# without
# a
# smile
# pass
# them
# yours
# ,
# Summarize
# :
# hey
# girl
# i
# just
# sent
# ya
# a
# message
# on
# Myspace
# ,
# Summarize
# :
# where`s
# the
# love?,Summarize
# :
# Oh
# ok
# ,
# Thanks
# .
# Dont
# know
# where
# the
# courthouse
# i
# d
# either
# ,
# I`ll
# learn
# though
# .
# Any
# nkotb
# ?
# Twitter
# stole
# my
# pic
# again
#
# it
# hates
# me
# [('Gotta', 210, 215, 'PERSON'), ('this morning', 233, 245, 'TIME'), ('this afternoon', 512, 526, 'TIME'), ('this week', 572, 581, 'DATE'), ('Thanx', 614, 619, 'PERSON'), ('500', 650, 653, 'MONEY'), ('UTI', 727, 730, 'ORG'), ('about 100000000000000000000000000000000000', 848, 890, 'CARDINAL'), ('up to', 948, 953, 'CARDINAL'), ('9', 954, 955, 'QUANTITY'), ('Brb', 1081, 1084, 'PERSON'), ('10', 1088, 1090, 'CARDINAL'), ('a Ken Onion Chive?,Summarize:', 1165, 1194, 'PERSON'), ('dang', 1194, 1198, 'PERSON'), ('congrats', 1334, 1342, 'PERSON'), ('Italian', 1424, 1431, 'NORP'), ('Haiku', 1460, 1465, 'NORP'), ('Michelle Yuen', 1486, 1499, 'PERSON'), ('a perfect day', 1521, 1534, 'DATE'), ('chicago', 1581, 1588, 'GPE'), ('8:20', 1595, 1599, 'TIME'), ('Summarize:_uk Yeah', 1621, 1639, 'PERSON'), ('32', 1682, 1684, 'CARDINAL'), ('North Shore Animal', 1712, 1730, 'GPE'), ('Dont', 2061, 2065, 'PERSON')]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Summarize: we should all be down to earth. don`t none of us walk on water  I`m just some **** nerd trying to find my way thru life lol,Summarize: umm how abt a comment like that :p 'i dont like this',Summarize:
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gotta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  go to the doctor
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#   i feel so sick right now. i can barely talk but i`m still yelling across the house lol,Summarize: busy wit work  how is your business going on?,Summarize: I hope the young`ins enjoyed your wisdom!,Summarize:In a rush....   Lunchtime anyway,Summarize: we had scones
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this afternoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# !! they were great  we`re gonna make cupcakes
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , on Wednesday!,Summarize:G`day
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thanx
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  for following.,Summarize:The $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  I saved on not buying a couch is going towards paying my visit to ER for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UTI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,Summarize:Still at work whaaaaaaaahhhh,Summarize:: Oh. The voting is over!  But don`t worry, I already voted for you
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 100000000000000000000000000000000000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  times earlier!!!,Summarize:This is scary  they hooked me
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     up to
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  wires n it printed sum graph ohhhhhh,Summarize:just got done washing dishes not too long ago,Summarize:Just going to shower.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  mins or so,Summarize:I`ve lost my pocket knife  Suggestions for replacing
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a Ken Onion Chive?,Summarize:
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dang
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  i miss you  goodnight,Summarize:My goodness! Another hit, another run!!!,Summarize:Thinkin` Twitter is interesting.,Summarize: woohoo!
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     congrats
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to your friend and the boyfriend.,Summarize:Buongiorno !!! woke up and of for my
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Italian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  lunch,Summarize:gives you a
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Haiku
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  status (inspired by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michelle Yuen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# )  the sun is shining
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a perfect day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  glorious day outside my office,Summarize:  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chicago
#     <span style="font-size: 0.8em;

# %%
# import
from learning_modules.t5tuning import T5

# instantiate
model = T5()

model.from_pretrained(model_type="t5", model_name="t5-base")
model.train(train_df=train_df[:5000],
            eval_df=test_df[:100], 
            source_max_token_len=128, 
            target_max_token_len=50, 
            batch_size=8, max_epochs=3, use_gpu=False)
